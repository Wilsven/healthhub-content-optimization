# %%
import glob
import os

import pandas as pd
import papermill as pm
from logger import logger

# %% [markdown]
# ## Generate Embeddings

# %%
notebook = "embeddings.ipynb"
pm.inspect_notebook(notebook)

# %%
# model_name = "all-MiniLM-L6-v2"
# model_name = "all-mpnet-base-v2"
model_name = "bge-large-en-v1.5"
owner_name = "BAAI"

for strategy in ["mean"]:
    logger.info(
        f"Running {notebook} for {model_name} model with {strategy} pooling strategy"
    )
    pm.execute_notebook(
        input_path="embeddings.ipynb",
        output_path=os.path.join(
            "..",
            "artifacts",
            "notebooks",
            f"{model_name}_{strategy}_emb.ipynb",
        ),
        parameters={
            "MODEL_NAME": model_name,
            "POOLING_STRATEGY": strategy,
            "OWNER": owner_name,
        },
    )

# %% [markdown]
# ## Evaluate Similarities

# %%
notebook = "similarity.ipynb"
pm.inspect_notebook(notebook)

# %%
method = "contextual_nn_based_embeddings"
model_name = "all-MiniLM-L6-v2"
# model_name = "all-mpnet-base-v2"
owner_name = "sentence-transformers"

for strategy in ["mean"]:
    logger.info(
        f"Running {notebook} for {model_name} model with {strategy} pooling strategy"
    )
    pm.execute_notebook(
        input_path="similarity.ipynb",
        output_path=os.path.join(
            "..",
            "artifacts",
            "notebooks",
            f"{model_name}_{strategy}_sim.ipynb",
        ),
        parameters={
            "MODEL_NAME": model_name,
            "POOLING_STRATEGY": strategy,
            "OWNER": owner_name,
            "METHOD": method,
        },
    )

# %% [markdown]
# ### Clustering and Graph Visualisation

# %%
notebook = "construct_graph.ipynb"
pm.inspect_notebook(notebook)
# Out:
# {'EMBEDDING_MODEL': {'name': 'EMBEDDING_MODEL',
#   'inferred_type_name': 'str',
#   'default': '"tfidf_cosine"',
#   'help': ''}}

# %%
glob.glob("../artifacts/outputs/*_similarity_score.csv")
# Out:
# ['../artifacts/outputs\\all-MiniLM-L6-v2_mean_similarity_score.csv',
#  '../artifacts/outputs\\all-mpnet-base-v1_mean_cos_similarity_score.csv',
#  '../artifacts/outputs\\all-mpnet-base-v2_mean_similarity_score.csv',
#  '../artifacts/outputs\\bge-large-en-v1.5-quant_mean_similarity_score.csv',
#  '../artifacts/outputs\\bge-large-en-v1.5_mean_similarity_score.csv',
#  '../artifacts/outputs\\bge-m3_mean_cos_similarity_score.csv',
#  '../artifacts/outputs\\bow_cosine_similarity_score.csv',
#  '../artifacts/outputs\\bow_dot_similarity_score.csv',
#  '../artifacts/outputs\\bow_euclidean_similarity_score.csv',
#  '../artifacts/outputs\\bow_manhattan_similarity_score.csv',
#  '../artifacts/outputs\\d2v_similarity_score.csv',
#  '../artifacts/outputs\\glove-wiki-gigaword-300_mean_cos_similarity_score.csv',
#  '../artifacts/outputs\\glove_50_mean_cos_similarity_score.csv',
#  '../artifacts/outputs\\gte-base-en-v1.5_mean_cos_similarity_score.csv',
#  '../artifacts/outputs\\jina-embeddings-v2-base-en_mean_cos_similarity_score.csv',
#  '../artifacts/outputs\\lda_cosine_similarity_score.csv',
#  '../artifacts/outputs\\lda_dot_similarity_score.csv',
#  '../artifacts/outputs\\lda_euclidean_similarity_score.csv',
#  '../artifacts/outputs\\lda_manhattan_similarity_score.csv',
#  '../artifacts/outputs\\lsa_cosine_similarity_score.csv',
#  '../artifacts/outputs\\lsa_dot_similarity_score.csv',
#  '../artifacts/outputs\\lsa_euclidean_similarity_score.csv',
#  '../artifacts/outputs\\lsa_manhattan_similarity_score.csv',
#  '../artifacts/outputs\\multi-qa-mpnet-base-cos-v1_mean_cos_similarity_score.csv',
#  '../artifacts/outputs\\multi-qa-mpnet-base-cos-v1_mean_dot_similarity_score.csv',
#  '../artifacts/outputs\\multi-qa-mpnet-base-cos-v1_mean_euclidean_similarity_score.csv',
#  '../artifacts/outputs\\multi-qa-mpnet-base-dot-v1_cls_dot_similarity_score.csv',
#  '../artifacts/outputs\\mxbai-embed-large-v1_mean_cos_similarity_score.csv',
#  '../artifacts/outputs\\mxbai-embed-large-v1_mean_similarity_score.csv',
#  '../artifacts/outputs\\nomic-embed-text-v1.5_mean_cos_similarity_score.csv',
#  '../artifacts/outputs\\snowflake-arctic-embed-m-long_mean_cos_similarity_score.csv',
#  '../artifacts/outputs\\stsb-mpnet-base-v2_mean_similarity_score.csv',
#  '../artifacts/outputs\\tfidf_cosine_similarity_score.csv',
#  '../artifacts/outputs\\tfidf_dot_similarity_score.csv',
#  '../artifacts/outputs\\tfidf_euclidean_similarity_score.csv',
#  '../artifacts/outputs\\tfidf_manhattan_similarity_score.csv',
#  '../artifacts/outputs\\tfidf_mean_similarity_score.csv']

# %%
variation_list = []

# %%
# Include models manually if it doesn't fall under statistical, contextual or sbert embedding method, such as doc2vec, glove embeddings
variation_list = [
    "glove-wiki-gigaword-300_mean_cos",
    "glove_50_mean_cos",
    "d2v",
    "gte-base-en-v1.5_mean_cos",
    "jina-embeddings-v2-base-en_mean_cos",
    "multi-qa-mpnet-base-cos-v1_mean_cos",
    "multi-qa-mpnet-base-cos-v1_mean_dot",
    "multi-qa-mpnet-base-cos-v1_mean_euclidean",
    "multi-qa-mpnet-base-dot-v1_cls_dot",
    "mxbai-embed-large-v1_mean_cos",
    "mxbai-embed-large-v1_mean",
    "nomic-embed-text-v1.5_mean_cos",
    "snowflake-arctic-embed-m-long_mean_cos",
    "bge-large-en-v1.5-quant_mean",
    "bge-m3_mean_cos",
    "all-mpnet-base-v1_mean_cos"
    # "glove",
]

# %%
methods_list = [
    "sbert_embeddings",
    "statistical_vector_based_embeddings",
    "contextual_nn_based_embeddings",
]
directory = "../artifacts/outputs/"

for method in methods_list:
    input_file = f"{directory}/{method}_similarity_score.xlsx"
    if os.path.isfile(input_file):
        excel = pd.ExcelFile(input_file)
        print(f"{method}: {excel.sheet_names}")
        for sheet_name in excel.sheet_names:
            df = pd.read_excel(input_file, sheet_name=sheet_name)
            output_file = f"{directory}/{sheet_name}_similarity_score.csv"
            df.to_csv(output_file, index=False)
        variation_list.extend(excel.sheet_names)

variation_list
# Out:
# sbert_embeddings: ['stsb-mpnet-base-v2_mean', 'all-mpnet-base-v2_mean']
# statistical_vector_based_embeddings: ['bow_cosine', 'bow_euclidean', 'bow_dot', 'bow_manhattan', 'tfidf_cosine', 'tfidf_euclidean', 'tfidf_dot', 'tfidf_manhattan', 'lsa_cosine', 'lsa_euclidean', 'lsa_dot', 'lsa_manhattan', 'lda_cosine', 'lda_euclidean', 'lda_dot', 'lda_manhattan']
# contextual_nn_based_embeddings: ['bge-large-en-v1.5_mean', 'all-MiniLM-L6-v2_mean']
# ['glove-wiki-gigaword-300_mean_cos',
#  'glove_50_mean_cos',
#  'd2v',
#  'gte-base-en-v1.5_mean_cos',
#  'jina-embeddings-v2-base-en_mean_cos',
#  'multi-qa-mpnet-base-cos-v1_mean_cos',
#  'multi-qa-mpnet-base-cos-v1_mean_dot',
#  'multi-qa-mpnet-base-cos-v1_mean_euclidean',
#  'multi-qa-mpnet-base-dot-v1_cls_dot',
#  'mxbai-embed-large-v1_mean_cos',
#  'mxbai-embed-large-v1_mean',
#  'nomic-embed-text-v1.5_mean_cos',
#  'snowflake-arctic-embed-m-long_mean_cos',
#  'bge-large-en-v1.5-quant_mean',
#  'bge-m3_mean_cos',
#  'all-mpnet-base-v1_mean_cos',
#  'stsb-mpnet-base-v2_mean',
#  'all-mpnet-base-v2_mean',
#  'bow_cosine',
#  'bow_euclidean',
#  'bow_dot',
#  'bow_manhattan',
#  'tfidf_cosine',
#  'tfidf_euclidean',
#  'tfidf_dot',
#  'tfidf_manhattan',
#  'lsa_cosine',
#  'lsa_euclidean',
#  'lsa_dot',
#  'lsa_manhattan',
#  'lda_cosine',
#  'lda_euclidean',
#  'lda_dot',
#  'lda_manhattan',
#  'bge-large-en-v1.5_mean',
#  'all-MiniLM-L6-v2_mean']

# %%
for em_model in variation_list:
    logger.info(f"Running {notebook} for {em_model} model")
    pm.execute_notebook(
        input_path=notebook,
        output_path=os.path.join(
            "..",
            "artifacts",
            "notebooks",
            f"{em_model}_construct_graph.ipynb",
        ),
        parameters={"EMBEDDING_MODEL": em_model},
    )
# Out:
# 2024-07-01 10:25:08,290 - Running construct_graph.ipynb for glove-wiki-gigaword-300_mean_cos model
# Executing: 100%|██████████| 21/21 [00:09<00:00,  2.13cell/s]
# 2024-07-01 10:25:18,194 - Running construct_graph.ipynb for glove_50_mean_cos model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.84cell/s]
# 2024-07-01 10:25:29,707 - Running construct_graph.ipynb for d2v model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.77cell/s]
# 2024-07-01 10:25:41,690 - Running construct_graph.ipynb for gte-base-en-v1.5_mean_cos model
# Executing: 100%|██████████| 21/21 [00:09<00:00,  2.19cell/s]
# 2024-07-01 10:25:51,354 - Running construct_graph.ipynb for jina-embeddings-v2-base-en_mean_cos model
# Executing: 100%|██████████| 21/21 [00:09<00:00,  2.22cell/s]
# 2024-07-01 10:26:00,871 - Running construct_graph.ipynb for multi-qa-mpnet-base-cos-v1_mean_cos model
# Executing: 100%|██████████| 21/21 [00:09<00:00,  2.26cell/s]
# 2024-07-01 10:26:10,232 - Running construct_graph.ipynb for multi-qa-mpnet-base-cos-v1_mean_dot model
# Executing: 100%|██████████| 21/21 [00:09<00:00,  2.17cell/s]
# 2024-07-01 10:26:19,970 - Running construct_graph.ipynb for multi-qa-mpnet-base-cos-v1_mean_euclidean model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.80cell/s]
# 2024-07-01 10:26:31,752 - Running construct_graph.ipynb for multi-qa-mpnet-base-dot-v1_cls_dot model
# Executing: 100%|██████████| 21/21 [00:12<00:00,  1.75cell/s]
# 2024-07-01 10:26:43,945 - Running construct_graph.ipynb for mxbai-embed-large-v1_mean_cos model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.79cell/s]
# 2024-07-01 10:26:55,789 - Running construct_graph.ipynb for mxbai-embed-large-v1_mean model
# Executing: 100%|██████████| 21/21 [00:12<00:00,  1.72cell/s]
# 2024-07-01 10:27:08,106 - Running construct_graph.ipynb for nomic-embed-text-v1.5_mean_cos model
# Executing: 100%|██████████| 21/21 [00:12<00:00,  1.73cell/s]
# 2024-07-01 10:27:20,378 - Running construct_graph.ipynb for snowflake-arctic-embed-m-long_mean_cos model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.77cell/s]
# 2024-07-01 10:27:32,365 - Running construct_graph.ipynb for bge-large-en-v1.5-quant_mean model
# Executing: 100%|██████████| 21/21 [00:12<00:00,  1.74cell/s]
# 2024-07-01 10:27:44,540 - Running construct_graph.ipynb for bge-m3_mean_cos model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.84cell/s]
# 2024-07-01 10:27:56,087 - Running construct_graph.ipynb for all-mpnet-base-v1_mean_cos model
# Executing: 100%|██████████| 21/21 [00:12<00:00,  1.73cell/s]
# 2024-07-01 10:28:08,359 - Running construct_graph.ipynb for stsb-mpnet-base-v2_mean model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.83cell/s]
# 2024-07-01 10:28:19,992 - Running construct_graph.ipynb for all-mpnet-base-v2_mean model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.79cell/s]
# 2024-07-01 10:28:31,888 - Running construct_graph.ipynb for bow_cosine model
# Executing: 100%|██████████| 21/21 [00:12<00:00,  1.74cell/s]
# 2024-07-01 10:28:44,162 - Running construct_graph.ipynb for bow_euclidean model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.76cell/s]
# 2024-07-01 10:28:56,204 - Running construct_graph.ipynb for bow_dot model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.77cell/s]
# 2024-07-01 10:29:08,182 - Running construct_graph.ipynb for bow_manhattan model
# Executing: 100%|██████████| 21/21 [00:12<00:00,  1.74cell/s]
# 2024-07-01 10:29:20,398 - Running construct_graph.ipynb for tfidf_cosine model
# Executing: 100%|██████████| 21/21 [00:12<00:00,  1.70cell/s]
# 2024-07-01 10:29:32,915 - Running construct_graph.ipynb for tfidf_euclidean model
# Executing: 100%|██████████| 21/21 [00:12<00:00,  1.75cell/s]
# 2024-07-01 10:29:45,088 - Running construct_graph.ipynb for tfidf_dot model
# Executing: 100%|██████████| 21/21 [00:09<00:00,  2.14cell/s]
# 2024-07-01 10:29:54,995 - Running construct_graph.ipynb for tfidf_manhattan model
# Executing: 100%|██████████| 21/21 [00:09<00:00,  2.17cell/s]
# 2024-07-01 10:30:04,746 - Running construct_graph.ipynb for lsa_cosine model
# Executing: 100%|██████████| 21/21 [00:09<00:00,  2.11cell/s]
# 2024-07-01 10:30:14,763 - Running construct_graph.ipynb for lsa_euclidean model
# Executing: 100%|██████████| 21/21 [00:09<00:00,  2.22cell/s]
# 2024-07-01 10:30:24,289 - Running construct_graph.ipynb for lsa_dot model
# Executing: 100%|██████████| 21/21 [00:09<00:00,  2.21cell/s]
# 2024-07-01 10:30:33,872 - Running construct_graph.ipynb for lsa_manhattan model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.76cell/s]
# 2024-07-01 10:30:45,921 - Running construct_graph.ipynb for lda_cosine model
# Executing: 100%|██████████| 21/21 [00:12<00:00,  1.71cell/s]
# 2024-07-01 10:30:58,377 - Running construct_graph.ipynb for lda_euclidean model
# Executing: 100%|██████████| 21/21 [00:09<00:00,  2.14cell/s]
# 2024-07-01 10:31:08,289 - Running construct_graph.ipynb for lda_dot model
# Executing: 100%|██████████| 21/21 [00:12<00:00,  1.72cell/s]
# 2024-07-01 10:31:20,643 - Running construct_graph.ipynb for lda_manhattan model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.79cell/s]
# 2024-07-01 10:31:32,556 - Running construct_graph.ipynb for bge-large-en-v1.5_mean model
# Executing: 100%|██████████| 21/21 [00:11<00:00,  1.89cell/s]
# 2024-07-01 10:31:43,822 - Running construct_graph.ipynb for all-MiniLM-L6-v2_mean model
# Executing: 100%|██████████| 21/21 [00:09<00:00,  2.13cell/s]

# %%
notebook = "clusterviz.ipynb"
pm.inspect_notebook(notebook)
# Out:
# {'EMBEDDING_MODEL': {'name': 'EMBEDDING_MODEL',
#   'inferred_type_name': 'None',
#   'default': '"tfidf"',
#   'help': ''}}

# %%
for em_model in variation_list:
    logger.info(f"Running {notebook} for {em_model} model")
    pm.execute_notebook(
        input_path=notebook,
        output_path=os.path.join(
            "..",
            "artifacts",
            "notebooks",
            f"{em_model}_clusterviz.ipynb",
        ),
        parameters={"EMBEDDING_MODEL": em_model},
    )
# Out:
# 2024-07-01 10:31:53,794 - Running clusterviz.ipynb for glove-wiki-gigaword-300_mean_cos model
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.96cell/s]
# 2024-07-01 10:31:58,867 - Running clusterviz.ipynb for glove_50_mean_cos model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.85cell/s]
# 2024-07-01 10:32:00,794 - Running clusterviz.ipynb for d2v model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.90cell/s]
# 2024-07-01 10:32:02,707 - Running clusterviz.ipynb for gte-base-en-v1.5_mean_cos model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  8.46cell/s]
# 2024-07-01 10:32:04,489 - Running clusterviz.ipynb for jina-embeddings-v2-base-en_mean_cos model
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.95cell/s]
# 2024-07-01 10:32:09,579 - Running clusterviz.ipynb for multi-qa-mpnet-base-cos-v1_mean_cos model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.92cell/s]
# 2024-07-01 10:32:11,489 - Running clusterviz.ipynb for multi-qa-mpnet-base-cos-v1_mean_dot model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.98cell/s]
# 2024-07-01 10:32:13,379 - Running clusterviz.ipynb for multi-qa-mpnet-base-cos-v1_mean_euclidean model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.91cell/s]
# 2024-07-01 10:32:15,284 - Running clusterviz.ipynb for multi-qa-mpnet-base-dot-v1_cls_dot model
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.95cell/s]
# 2024-07-01 10:32:20,383 - Running clusterviz.ipynb for mxbai-embed-large-v1_mean_cos model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  8.00cell/s]
# 2024-07-01 10:32:22,269 - Running clusterviz.ipynb for mxbai-embed-large-v1_mean model
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.95cell/s]
# 2024-07-01 10:32:27,371 - Running clusterviz.ipynb for nomic-embed-text-v1.5_mean_cos model
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.91cell/s]
# 2024-07-01 10:32:32,533 - Running clusterviz.ipynb for snowflake-arctic-embed-m-long_mean_cos model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.88cell/s]
# 2024-07-01 10:32:34,450 - Running clusterviz.ipynb for bge-large-en-v1.5-quant_mean model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.84cell/s]
# 2024-07-01 10:32:36,373 - Running clusterviz.ipynb for bge-m3_mean_cos model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.81cell/s]
# 2024-07-01 10:32:38,303 - Running clusterviz.ipynb for all-mpnet-base-v1_mean_cos model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.84cell/s]
# 2024-07-01 10:32:40,231 - Running clusterviz.ipynb for stsb-mpnet-base-v2_mean model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  8.28cell/s]
# 2024-07-01 10:32:42,056 - Running clusterviz.ipynb for all-mpnet-base-v2_mean model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.91cell/s]
# 2024-07-01 10:32:43,959 - Running clusterviz.ipynb for bow_cosine model
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.95cell/s]
# 2024-07-01 10:32:49,049 - Running clusterviz.ipynb for bow_euclidean model
# Executing: 100%|██████████| 15/15 [00:03<00:00,  4.43cell/s]
# 2024-07-01 10:32:52,459 - Running clusterviz.ipynb for bow_dot model
# Executing: 100%|██████████| 15/15 [00:02<00:00,  6.70cell/s]
# 2024-07-01 10:32:54,719 - Running clusterviz.ipynb for bow_manhattan model
# Executing: 100%|██████████| 15/15 [00:06<00:00,  2.48cell/s]
# 2024-07-01 10:33:00,776 - Running clusterviz.ipynb for tfidf_cosine model
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.93cell/s]
# 2024-07-01 10:33:05,903 - Running clusterviz.ipynb for tfidf_euclidean model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.78cell/s]
# 2024-07-01 10:33:07,842 - Running clusterviz.ipynb for tfidf_dot model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.77cell/s]
# 2024-07-01 10:33:09,788 - Running clusterviz.ipynb for tfidf_manhattan model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.78cell/s]
# 2024-07-01 10:33:11,724 - Running clusterviz.ipynb for lsa_cosine model
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.96cell/s]
# 2024-07-01 10:33:16,813 - Running clusterviz.ipynb for lsa_euclidean model
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.96cell/s]
# 2024-07-01 10:33:21,901 - Running clusterviz.ipynb for lsa_dot model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.71cell/s]
# 2024-07-01 10:33:23,858 - Running clusterviz.ipynb for lsa_manhattan model
# Executing: 100%|██████████| 15/15 [00:02<00:00,  6.93cell/s]
# 2024-07-01 10:33:26,036 - Running clusterviz.ipynb for lda_cosine model
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.76cell/s]
# 2024-07-01 10:33:31,493 - Running clusterviz.ipynb for lda_euclidean model
# Executing: 100%|██████████| 15/15 [00:03<00:00,  4.18cell/s]
# 2024-07-01 10:33:35,087 - Running clusterviz.ipynb for lda_dot model
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.72cell/s]
# 2024-07-01 10:33:40,617 - Running clusterviz.ipynb for lda_manhattan model
# Executing: 100%|██████████| 15/15 [00:05<00:00,  2.57cell/s]
# 2024-07-01 10:33:46,475 - Running clusterviz.ipynb for bge-large-en-v1.5_mean model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.99cell/s]
# 2024-07-01 10:33:48,362 - Running clusterviz.ipynb for all-MiniLM-L6-v2_mean model
# Executing: 100%|██████████| 15/15 [00:01<00:00,  7.82cell/s]
